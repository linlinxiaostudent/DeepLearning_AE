# %%
import pandas as pd
import numpy as np
import jieba

# %%
from keras.preprocessing import sequence
from keras.optimizers import SGD,RMSprop,Adagrad
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense,Dropout,Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM,GRU

# %%
neg=pd.read_excel('neg.xls',header=None,index=None)
pos = pd.read_excel ('pos.xls',header = None,index = None)

# %%
print(pos.index)
# Out:
# RangeIndex(start=0, stop=10677, step=1)

# %%
print(pos.head())
# Out:
#                                                    0
# 0  做父母一定要有刘墉这样的心态，不断地学习，不断地进步，不断地给自己补充新鲜血液，让自己保持一...
# 1  作者真有英国人严谨的风格，提出观点、进行论述论证，尽管本人对物理学了解不深，但是仍然能感受到...
# 2  作者长篇大论借用详细报告数据处理工作和计算结果支持其新观点。为什么荷兰曾经县有欧洲最高的生产...
# 3  作者在战几时之前用了＂拥抱＂令人叫绝．日本如果没有战败，就有会有美军的占领，没胡官僚主义的延...
# 4  作者在少年时即喜阅读，能看出他精读了无数经典，因而他有一个庞大的内心世界。他的作品最难能可贵...

# %%
pos['mark']=1
neg['mark']=0
pn =pd.concat([pos,neg],ignore_index=True)
neglen=len(neg)
poslen=len(pos)
cw = lambda x: list(jieba.cut(x))
pn['words']= pn[0].apply(cw)
print(pn)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lulinlin\AppData\Local\Temp\jieba.cache
# Loading model cost 1.256 seconds.
# Prefix dict has been built succesfully.
#                                                        0  mark  \
# 0      做父母一定要有刘墉这样的心态，不断地学习，不断地进步，不断地给自己补充新鲜血液，让自己保持一...     1
# 1      作者真有英国人严谨的风格，提出观点、进行论述论证，尽管本人对物理学了解不深，但是仍然能感受到...     1
# 2      作者长篇大论借用详细报告数据处理工作和计算结果支持其新观点。为什么荷兰曾经县有欧洲最高的生产...     1
# 3      作者在战几时之前用了＂拥抱＂令人叫绝．日本如果没有战败，就有会有美军的占领，没胡官僚主义的延...     1
# 4      作者在少年时即喜阅读，能看出他精读了无数经典，因而他有一个庞大的内心世界。他的作品最难能可贵...     1
# 5      作者有一种专业的谨慎，若能有幸学习原版也许会更好，简体版的书中的印刷错误比较多，影响学者理解...     1
# 6      作者用诗一样的语言把如水般清澈透明的思想娓娓道来，像一个经验丰富的智慧老人为我们解开一个又一...     1
# 7      作者提出了一种工作和生活的方式，作为咨询界的元老，不仅能提出理念，而且能够身体力行地实践，并...     1
# 8      作者妙语连珠，将整个60-70年代用层出不穷的摇滚巨星与自身故事紧紧相连什么是乡愁？什么是摇...     1
# 9      作者逻辑严密，一气呵成。没有一句废话，深入浅出，循循善诱，环环相扣。让平日里看到指标图释就头...     1
# 10     作者力从马克思注意经济学角度来剖析当代中国经济细心的人会发现中国近20年来的一些政策措施在何...     1
# 11     作者结合希尔和卡耐基、汪中求等大师的一些观点，结合中国的实际情况，给渴望成功的青年指出一条实...     1
# 12     作者更多的是从圆圆母亲的角度来写这个文章。90%的例子都是以圆圆为中心的。我认为，例证不够充...     1
# 13     作者对于某些电影“表面粗糙”、“内里光滑”的分析，可谓入木三分，为理解那些貌似触及现实而又让...     1
# 14     作者的理念很好，主要是看一个公司的内部情况来决定股票的情况。操作比较难，作者也承认，所以他说...     1
# 15     作者的观点独特，语言犀利，深刻的总结了男人与女人之间的是非恩怨，把男人与女人在生活中积累的宿...     1
# 16     作者的笔触很真实 将一个不忠却又深爱自己妻子的丈夫形象毫无遮掩的展示给读者 而什么是真爱 什...     1
# 17     作者笔下留情啊，深圳的自由作家远远没有《离婚未遂》笔下那么潇洒。事实上，深圳是一个典型的伪文...     1
# 18     作者被认为是“爱的奇迹天使”，确实是这样的。很多人认为与孩子的相处一定充满快乐，但却不知一份...     1
# 19     作为有史以来最伟大的基金经理彼得&#183;林奇凭借其在投资领域杰出的贡献，终其一生的经验和...     1
# 20     作为一名山西太谷人，从小听多了有关晋商的故事，也去过许多山西的地方，但由于离家已久，故乡渐渐...     1
# 21     作为一名“白骨精”，我不得不佩服作者入木三分的刻画，不仅精准地描绘出我们的生活画面，更深刻地...     1
# 22     作为一本职场启示录，不错没有像杜拉拉一样的引入胜的故事，却也用轻松的方式告诉你，如何在职场中...     1
# 23     作为一本屹立不倒的经典教材，纽摄所传授的不是单纯的技术，而是理念。不是教条的灌输，而是互动性...     1
# 24     作为一本西方人创作的心理学读物，还是以西方人的视角来看待问题的方式来阐述，目前刚刚开始读，但...     1
# 25     作为推理小说可能不是最好的，作为言情小说可能也不是最好的。但是结合在一起却很让人惊奇。羡慕那...     1
# 26     作为女儿6.1的礼物。虽然晚到了几天。等拿到的时候，女儿爱不释手，上洗手间也看，告知不好。竟...     1
# 27     作为妈妈，我个人很喜欢这本书，但是仍在怀疑这本书是否适合给孩子看？这本书以孩子的视角观看我们...     1
# 28     昨晚看着看着就睡着了，今天早晨醒来就立马抓起继续啃，正逢小说结尾部分，也正如作者的期望，我被...     1
# 29     昨天我把这套书看完了，结尾我不是很喜欢有点太戏剧了，但对书中的主人公却是最好的安排，我去过新...     1
# ...                                                  ...   ...
# 21075  买完降价了，店家服务还不错，但安装售后太黑了安装费竟然漫天要价，一开口要378，我不肯买单，...     0
# 21076  从淘宝客服到送货小哥再到售后检测，态度都很好，都很满意，但是当热水器温度加热到最高温度电源自...     0
# 21077                          帮别人买的，说很好，就是顺丰慢了点，不过还可以了，     0
# 21078  良好信誉的商家从小细节做起，抽奖抽到一半球热水壶上面居然写着 真货&rdquo;！！！！还有...     0
# 21079                 买完后去实体店看了下50升的才680元，没想到比网购还便宜，买贵了。     0
# 21080  安装费超级贵本来说几十块，安完竟然200块，自己买材料，安装师傅还不给装。卖家倒是服务很好，...     0
# 21081                                 还好很美观，安装费太贵花了190元。     0
# 21082    商品包装很好，做工很好！性价比高！但是太原这边Media安装人员收费不便宜，安装用了195元。     0
# 21083  东西不错，现在这个天早上把水烧到最热断电，晚上回去还可以洗澡。就是这款太老了，没有定时器，不...     0
# 21084                               安全阀那略有问题，不过总体不错，好评吧。     0
# 21085                                 东西不错有的速度很快就是安装师傅黑点     0
# 21086                             好，物流也快，就是安装费花了200，有点贵。     0
# 21087                 东西已经装好了，工人师傅挺好的，就是真的好贵，装完要200，太贵了！     0
# 21088  安装打美的客服电话就可以免费装了，但最好备好材料：3条喉管，1个三通。安装虽然免费，但安装师...     0
# 21089  东西装修好了，也不知道好不好，可是售后太黑了！买了两个400多的配件费！都无语了！本来在网上...     0
# 21090           昨天刚装好，试用了一下，不错，家里都有热水了，值得购买的东东。就是安装费好贵啊。     0
# 21091  加热不是很快，昨天安装上就用了，洗澡洗了半个小时就变成冷水了，不知道是机器的事还是我的事。不...     0
# 21092                  好评 就是安装用的件有点贵 花了160 建议亲们自己买东西让售后安     0
# 21093                    很满意 就是安装材料费有点贵花了两百多 棒！ 客服很好 很认真     0
# 21094  还没装上去，美的货信得过哈哈！不过物流真心麻烦，明明是市区，居然要跑到30公里外收货，对物流...     0
# 21095  热水器用了一个星期收到！和客服沟通了下，现在就如实评价！！！热水器冷热调节相当不灵敏，太热了...     0
# 21096  刚开始说好了，有一个四件套，结果给我忘了发，后来补发8天才到。还说什么浴巾就是两根破毛巾。质...     0
# 21097  客服骗人 不是恒温又说是恒温 噪音大 燃气的味道浓 10号开始使用 17号马上没有热水出 差差差差     0
# 21098                               厨宝还好吧  但那赠品送了也跟没送差不多     0
# 21099  恰逢春节期间，没有安装工人，所以自己动手两块后安装好了，用不了半小时，效果不错，只是送的赠品...     0
# 21100         安装我自己花了500多，美的够黑心的，真的是烦心，安装的售后叼的要死！差评！！！！！     0
# 21101              东西不错，售后太差，安装一个热水器400块钱，像话吗？钱给完了发现被黑了！     0
# 21102  碰到最差的、最骗人的卖家，好吧，我倒霉！这个卖家太不厚道了，显示所在地上海，我买这个热水器选...     0
# 21103                                    宝贝不错，物流也不错，售后差，     0
# 21104  美的售后太垃圾，其他售后都是两小时回电话，美的是24小时，结果超过市区不到五公里问我收五十，...     0
#
#                                                    words
# 0      [做, 父母, 一定, 要, 有, 刘墉, 这样, 的, 心态, ，, 不断, 地, 学习,...
# 1      [作者, 真有, 英国人, 严谨, 的, 风格, ，, 提出, 观点, 、, 进行, 论述,...
# 2      [作者, 长篇大论, 借用, 详细, 报告, 数据处理, 工作, 和, 计算结果, 支持, ...
# 3      [作者, 在, 战, 几时, 之前, 用, 了, ＂, 拥抱, ＂, 令人, 叫绝, ．, ...
# 4      [作者, 在, 少年, 时即, 喜, 阅读, ，, 能, 看出, 他, 精读, 了, 无数,...
# 5      [作者, 有, 一种, 专业, 的, 谨慎, ，, 若能, 有幸, 学习, 原版, 也许, ...
# 6      [作者, 用, 诗, 一样, 的, 语言, 把, 如水般, 清澈, 透明, 的, 思想, 娓...
# 7      [作者, 提出, 了, 一种, 工作, 和, 生活, 的, 方式, ，, 作为, 咨询, 界...
# 8      [作者, 妙语连珠, ，, 将, 整个, 60, -, 70, 年代, 用, 层出不穷, 的...
# 9      [作者, 逻辑, 严密, ，, 一气呵成, 。, 没有, 一句, 废话, ，, 深入浅出, ...
# 10     [作者, 力, 从, 马克思, 注意, 经济学, 角度, 来, 剖析, 当代, 中国, 经济...
# 11     [作者, 结合, 希尔, 和, 卡耐基, 、, 汪中求, 等, 大师, 的, 一些, 观点,...
# 12     [作者, 更, 多, 的, 是从, 圆圆, 母亲, 的, 角度, 来, 写, 这个, 文章,...
# 13     [作者, 对于, 某些, 电影, “, 表面, 粗糙, ”, 、, “, 内里, 光滑, ”...
# 14     [作者, 的, 理念, 很, 好, ，, 主要, 是, 看, 一个, 公司, 的, 内部, ...
# 15     [作者, 的, 观点, 独特, ，, 语言, 犀利, ，, 深刻, 的, 总结, 了, 男人...
# 16     [作者, 的, 笔触, 很, 真实,  , 将, 一个, 不忠, 却, 又, 深爱, 自己,...
# 17     [作者, 笔下留情, 啊, ，, 深圳, 的, 自由, 作家, 远远, 没有, 《, 离婚,...
# 18     [作者, 被, 认为, 是, “, 爱, 的, 奇迹, 天使, ”, ，, 确实, 是, 这...
# 19     [作为, 有史以来, 最, 伟大, 的, 基金, 经理, 彼得, &#, 183, ;, 林...
# 20     [作为, 一名, 山西, 太谷, 人, ，, 从小, 听, 多, 了, 有关, 晋商, 的,...
# 21     [作为, 一名, “, 白骨精, ”, ，, 我, 不得不, 佩服, 作者, 入木三分, 的...
# 22     [作为, 一本, 职场, 启示录, ，, 不错, 没有, 像, 杜, 拉拉, 一样, 的, ...
# 23     [作为, 一本, 屹立, 不倒, 的, 经典, 教材, ，, 纽摄, 所, 传授, 的, 不...
# 24     [作为, 一本, 西方人, 创作, 的, 心理学, 读物, ，, 还是, 以, 西方人, 的...
# 25     [作为, 推理小说, 可能, 不是, 最好, 的, ，, 作为, 言情小说, 可能, 也, ...
# 26     [作为, 女儿, 6.1, 的, 礼物, 。, 虽然, 晚到, 了, 几天, 。, 等, 拿...
# 27     [作为, 妈妈, ，, 我, 个人, 很, 喜欢, 这, 本书, ，, 但是, 仍, 在, ...
# 28     [昨晚, 看着, 看着, 就, 睡着, 了, ，, 今天, 早晨, 醒来, 就, 立马, 抓...
# 29     [昨天, 我, 把, 这, 套书, 看, 完, 了, ，, 结尾, 我, 不是, 很, 喜欢...
# ...                                                  ...
# 21075  [买, 完, 降价, 了, ，, 店家, 服务, 还, 不错, ，, 但, 安装, 售后, ...
# 21076  [从, 淘宝, 客服, 到, 送货, 小哥, 再, 到, 售后, 检测, ，, 态度, 都,...
# 21077  [帮别人, 买, 的, ，, 说, 很, 好, ，, 就是, 顺丰慢, 了, 点, ，, 不...
# 21078  [良好信誉, 的, 商家, 从小, 细节, 做起, ，, 抽奖, 抽到, 一, 半球, 热,...
# 21079  [买, 完后, 去, 实体店, 看, 了, 下, 50, 升, 的, 才, 680, 元, ...
# 21080  [安装费, 超级, 贵, 本来, 说, 几十块, ，, 安完, 竟然, 200, 块, ，,...
# 21081           [还好, 很, 美观, ，, 安装费, 太贵, 花, 了, 190, 元, 。]
# 21082  [商品, 包装, 很, 好, ，, 做工, 很, 好, ！, 性价比, 高, ！, 但是, ...
# 21083  [东西, 不错, ，, 现在, 这个, 天, 早上, 把, 水烧, 到, 最, 热, 断电,...
# 21084       [安全阀, 那, 略有, 问题, ，, 不过, 总体, 不错, ，, 好评, 吧, 。]
# 21085             [东西, 不错, 有, 的, 速度, 很快, 就是, 安装, 师傅, 黑点]
# 21086  [好, ，, 物流, 也, 快, ，, 就是, 安装费, 花, 了, 200, ，, 有点,...
# 21087  [东西, 已经, 装好, 了, ，, 工人, 师傅, 挺, 好, 的, ，, 就是, 真的,...
# 21088  [安装, 打, 美的, 客服, 电话, 就, 可以, 免费, 装, 了, ，, 但, 最好,...
# 21089  [东西, 装修, 好, 了, ，, 也, 不, 知道, 好不好, ，, 可是, 售后, 太黑...
# 21090  [昨天, 刚装, 好, ，, 试用, 了, 一下, ，, 不错, ，, 家里, 都, 有, ...
# 21091  [加热, 不是, 很快, ，, 昨天, 安装, 上, 就, 用, 了, ，, 洗澡, 洗, ...
# 21092  [好评,  , 就是, 安装, 用, 的, 件, 有点, 贵,  , 花, 了, 160, ...
# 21093  [很, 满意,  , 就是, 安装, 材料费, 有点, 贵花, 了, 两百多,  , 棒, ...
# 21094  [还, 没, 装上去, ，, 美的, 货, 信得过, 哈哈, ！, 不过, 物流, 真心, ...
# 21095  [热水器, 用, 了, 一个, 星期, 收到, ！, 和, 客服, 沟通, 了, 下, ，,...
# 21096  [刚, 开始, 说好, 了, ，, 有, 一个, 四件套, ，, 结果, 给, 我, 忘, ...
# 21097  [客服, 骗人,  , 不是, 恒温, 又, 说, 是, 恒温,  , 噪音, 大,  , ...
# 21098  [厨宝, 还好, 吧,  ,  , 但, 那, 赠品, 送, 了, 也, 跟, 没, 送, ...
# 21099  [恰逢, 春节, 期间, ，, 没有, 安装工人, ，, 所以, 自己, 动手, 两块, 后...
# 21100  [安装, 我, 自己, 花, 了, 500, 多, ，, 美的, 够, 黑心, 的, ，, ...
# 21101  [东西, 不错, ，, 售后, 太, 差, ，, 安装, 一个, 热水器, 400, 块钱,...
# 21102  [碰到, 最差, 的, 、, 最, 骗人, 的, 卖家, ，, 好, 吧, ，, 我, 倒霉...
# 21103                [宝贝, 不错, ，, 物流, 也, 不错, ，, 售后, 差, ，]
# 21104  [美的, 售后, 太, 垃圾, ，, 其他, 售后, 都, 是, 两, 小时, 回, 电话,...
#
# [21105 rows x 3 columns]

# %%
comment = pd.read_excel('sum.xls')
comment = comment[comment['rateContent'].notnull()]
comment['words'] =comment['rateContent'].apply(cw)
d2v_train = pd.concat([pn['words'],comment['words']],ignore_index = True)
w=[]
for i in d2v_train:
    w.extend(i)
print(w[:20])
# Out:
# ['做', '父母', '一定', '要', '有', '刘墉', '这样', '的', '心态', '，', '不断', '地', '学习', '，', '不断', '地', '进步', '，', '不断', '地']

# %%
dict = pd.DataFrame(pd.Series(w).value_counts())
#print(dict[:20])
print(dict.values)
print(dict.index)
# Out:
# [[131885]
#  [ 85960]
#  [ 49352]
#  ...,
#  [     1]
#  [     1]
#  [     1]]
# Index(['，', '的', '。', '了', '是', '很', ' ', '我', '！', ',',
#        ...
#        'PS2', '规程', '造浪', '推给', '大错', '拿书', '升空', '万古', 'K197', '哈爾住'],
#       dtype='object', length=52964)

# %%
dict['id']= list(range(1,len(dict)+1))
print(dict['id'])
get_sent = lambda x: list(dict['id'][x])

# %%
pn['sent'] = pn['words'].apply(get_sent) #速度太慢，求出现的排名
maxlen = 50

# %%
print('Pad sequences( samples x time)')
# Out:
# Pad sequences( samples x time)

# %%
pn['sent'] = list(sequence.pad_sequences(pn['sent'],maxlen = maxlen))

# %%
x = np.array(list(pn['sent']))[::2]#训练集
y = np.array(list(pn['mark']))[::2]
xt = np.array(list(pn['sent']))[1::2] #测试集
yt = np.array(list(pn['mark']))[1::2]
xa = np.array(list(pn['sent'])) #全集
ya = np.array(list(pn['mark']))

# %%
print('Build model...')
model = Sequential()
model.add(Embedding(len(dict) + 1, 256))
model.add(LSTM(128))  # try using a GRU instead, for fun
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(xa, ya, batch_size=1, epochs=1 )  # 训练时间为若干个小时

classes = model.predict_classes(xa)
acc = np_utils.accuracy(classes, yt)

print('Test accuracy:',acc)
